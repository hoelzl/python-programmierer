# %% [markdown]
# <img src="img/python-logo-notext.svg"
#      style="display:block;margin:auto;width:10%"/>
# <br>
# <div style="text-align:center; font-size:200%;"><b>Quickstart</b></div>
# <br/>
# <div style="text-align:center;">Dr. Matthias Hölzl</div>

# %% [markdown]
# # Python und Jupyter Notebooks
#
# Wir beginnen mit einer kurzen Einführung in die Arbeitsweise von Python und
# Jupyter Notebooks.

# %% [markdown]
# ## Compiler (C++)
#
# <img src="img/compiler.svg" style="width:60%;margin:auto"/>

# %% [markdown]
# ## Interpreter (Python)
#
# <img src="img/interpreter.svg" style="width:60%;margin:auto"/>

# %% [markdown]
# ## Jupyter Notebooks
#
# <img src="img/jupyter-notebook.svg" style="width:60%;margin:auto"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

page_load_time = np.random.normal(3.0, 1.0, 1000)
purchase_amount = np.random.normal(50.0, 1.5, 1000) - page_load_time

plt.figure(figsize=(16, 8))
plt.scatter(page_load_time, purchase_amount)

# %% [markdown]
# ## Variablen und Datentypen
#
# Zahlen und Arithmetik:

# %%
17
# Out:
# 17

# %%
1.5 + 7.5
# Out:
# 9.0

# %%
1 + 2 * 3
# Out:
# 7

# %% [markdown]
# ## Zeichenketten

# %%
"This is a string"
# Out:
# 'This is a string'

# %%
'This is also a string'
# Out:
# 'This is also a string'

# %%
str(1 + 2)
# Out:
# '3'

# %%
"abc" + "def"
# Out:
# 'abcdef'

# %%
"abc" "def"
# Out:
# 'abcdef'

# %% [markdown]
# ### Variablen

# %%
answer = 42

# %%
answer
# Out:
# 42

# %%
my_value = answer + 2

# %%
my_value
# Out:
# 44

# %% [markdown]
# ## Jupyter Notebooks: Anzeige von Werten
#
# - Jupyter Notebooks geben den letzten Wert jeder Zelle auf dem Bildschirm aus
# - Das passiert in "normalen" Python-Programmen nicht!
#   - Wenn sie als Programme ausgeführt werden
#   - Der interaktive Interpreter verhält sich ähnlich wie Notebooks

# %%
123
# Out:
# 123

# %% [markdown]
# Um die Ausgabe des letzten Wertes einer Zelle in Jupyter zu unterbinden
# kann man die Zeile mit einem Strichpunkt beenden:

# %%
123
# Out:
# 123

# %%
123;

# %% [markdown]
# Jupyter zeigt auch den Wert von Variablen an:

# %%
answer
# Out:
# 42

# %%
my_value
# Out:
# 44

# %%
answer
my_value
# Out:
# 44

# %% [markdown]
# Um mehrere Werte anzuzeigen kann man die `print()`-Funktion verwenden:
#
# `print(...)` gibt den in Klammern eingeschlossenen Text auf dem Bildschirm
# aus.

# %%
print(123)
# Out:
# 123

# %%
print("asdf")
# Out:
# asdf

# %%
print(answer)
# Out:
# 42

# %%
print(answer)
print(my_value)
# Out:
# 42
# 44

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# Vergleichen Sie die Ausgabe mit der folgenden Zelle:

# %%
"Hello, world!"
# Out:
# 'Hello, world!'

# %%
print("answer =", answer)
# Out:
# answer = 42

# %%
print("answer =", answer, "my_value", my_value)
# Out:
# answer = 42 my_value 44

# %%
print("2 * 3 + answer =", 2 * 3 + answer)
# Out:
# 2 * 3 + answer = 48

# %%
print("a", "b", "c", sep="")
# Out:
# abc

# %%
answer
# Out:
# 21

# %%
print("answer = ", answer, "; my_value = ", my_value, sep="")
# Out:
# answer = 21; my_value = 44

# %%
print(f"answer = {answer}; my_value = {my_value}")
# Out:
# answer = 21; my_value = 44

# %%
print("working...", end="")
print("done")
# Out:
# working...done

# %% [markdown]
# ## Typen

# %%
type(123)
# Out:
# int

# %%
type("Foo")
# Out:
# str

# %%
answer = 42
print(type(answer))
print(answer)
# Out:
# <class 'int'>
# 42

# %% [markdown]
# ### Vordefinierte Funktionen

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
int("123")
# Out:
# 123

# %%
int(3.9999)
# Out:
# 3

# %%
round(4.4)
# Out:
# 4

# %%
round(4.6)
# Out:
# 5

# %%
print(round(0.5), round(1.5), round(2.5), round(3.5))
# Out:
# 0 2 2 4

# %% [markdown]
# ## Funktionen

# %%
def add_1(n):
    return n + 1

# %%
x = add_1(10)
x
# Out:
# 12
# 11

# %%
add_1(5) + add_1(7)
# Out:
# 14

# %%
def my_round(n):
    return int(n + 0.5)

# %%
my_round(3.5)
# Out:
# 4

# %%
print(my_round(0.5), my_round(1.5), my_round(2.5), my_round(3.5))
# Out:
# 1 2 3 4

# %% [markdown]
# ### Micro-Workshop
#
# Schreiben Sie eine Funktion `greeting(name)`, die eine Begrüßung in der Form
# "Hallo *name*!" auf dem Bildschirm ausgibt, z.B.
# ```python
# >>> greeting("Max")
# Hallo Max!
# >>>
# ```

# %%
def greeting(name):
    print("Hallo ", name, "!", sep="")

# %%
greeting("Max")
# Out:
# Hallo Max!

# %% [markdown]
# ### Methoden

# %%
my_str = "Foo"
my_str.lower()
# Out:
# 'foo'

# %%
len(my_str)
# Out:
# 3

# %%
number = 5

# %%
# Out:
# 3

# %% [markdown]
# ### Mehrere Parameter, Default Argumente

# %%
def add3(a, b=0, c=0):
    return a + b + c

# %%
add3(1, 3, 5)
# Out:
# 9

# %%
add3(1, 3)
# Out:
# 4

# %%
add3(1)
# Out:
# 1

# %%
add3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 add3()
#
# TypeError: add3() missing 1 required positional argument: 'a'

# %% [markdown]
# ### Verschachtelte Funktionsaufrufe

# %%
add3(add3(1, 2, 3), add3(2, 3, 4))
# Out:
# 15

# %% [markdown]
# ### Typannotationen

# %%
def mult(a: int, b: float):
    return a * b

# %%
mult(3, 2.0)
# Out:
# 6.0

# %%
mult("abc", 3)
# Out:
# 'abcabcabc'

# %%
"x" * 3
# Out:
# 'xxx'

# %% [markdown]
# ## Listen und Tupel

# %%
def add_1(n):
    return n + 1

# %%
numbers = [1, 2, 3, add_1(3)]
numbers
# Out:
# [1, 2, 3, 4]

# %%
print(numbers[0], numbers[3], numbers[-1], numbers[len(numbers) - 1])
# Out:
# 1 4 4 4

# %%
numbers + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 4, 5, 6]

# %%
numbers
# Out:
# [1, 2, 3, 4]

# %%
[None] * 3
# Out:
# [None, None, None]

# %%
my_list = []
my_list
your_list = my_list
my_list, your_list
# Out:
# ([], [])

# %%
my_list.append(1)
my_list, your_list
# Out:
# ([1], [1])

# %%
my_list.append(2)
my_list, your_list
# Out:
# ([1, 2], [1, 2])

# %%
my_list = ["1", "b", "c"]
my_list
# Out:
# ['1', 'b', 'c']

# %%
my_list[0]
# Out:
# '1'

# %%
not(True)
# Out:
# False

# %%
not False
# Out:
# True

# %%
"x" not in my_list
# Out:
# True

# %%
25 in my_list
# Out:
# False

# %%
my_list
# Out:
# ['1', 'b', 'c']

# %%
my_list.index("1")
# Out:
# 0

# %%
my_list.index("b")
# Out:
# 1

# %%
my_list[my_list.index("b")]
# Out:
# 'b'

# %%
my_list = [1, 2, 3, 4, 1, 2, 3, 4]

# %%
my_list.index(1)
# Out:
# 0

# %%
my_list.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 my_list.index(0)
#
# ValueError: 0 is not in list

# %% [markdown]
# ## Boole'sche Werte und `if`-Anweisungen

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
value = True
value
# Out:
# True

# %%
if value:
    print("Wahr")
else:
    print("False")
# Out:
# Wahr

# %%
def print_size(n):
    if n < 10:
        print("Very small")
    elif n < 15:
        print("Pretty small")
    elif n < 30:
        print("Average")
    else:
        print("Large")

# %%
print_size(1)
print_size(10)
print_size(20)
print_size(100)
# Out:
# Very small
# Pretty small
# Average

# %% [markdown]
# ### Micro-Workshop
#
# Schreiben Sie eine Funktion `fits_in_line(text: str, line_length: int = 72)`,
# die `True` oder `False` zurückgibt, je nachdem ob `text` in einer Zeile der
# Länge `line_length` ausgegeben werden kann oder nicht:
# ```python
# >>> fits_in_line("Hallo")
# True
# >>> fits_in_line("Hallo", 3)
# False
# >>>
# ```
#
# Schreiben Sie eine Funktion `print_line(text: str, line_length:int = 72)`,
# die
# * `text` auf dem Bildschirm ausgibt, falls das in einer Zeile der Länge
#   `line_length` möglich ist
# * `...` ausgibt, falls das nicht möglich ist.
#
# ```python
# >>> print_line("Hallo")
# Hallo
# >>> print_line("Hallo", 3)
# ...
# >>>
# ```

# %% [markdown]
# ## `for`-Schleifen

# %%
my_list = ["red", "green", "blue"]

# %%
for color in my_list:
    print("Color: " + color)
    print("Done")
# Out:
# Color: red
# Done
# Color: green
# Done
# Color: blue
# Done

# %%
for char in "abc":
    print(char)
# Out:
# a
# b
# c

# %%
squares = []
for number in [1, 2, 3]:
    squares.append(number ** 2)
squares
# Out:
# [1, 4, 9]

# %%
# Out:
# 3

# %% [markdown]
# ### Micro-Workshop
#
# Schreiben Sie eine Funktion `print_all(items: list)`, die die Elemente der
# Liste `items` auf dem Bildschirm ausgibt, jeweils ein Element pro Zeile:
#
# ```python
# >>> print_all([1, 2, 3])
# 1
# 2
# 3
# >>>
# ```
# Was passiert, wenn Sie die Funktion mit einem String als Argument aufrufen,
# z.B. `print_all("abc")`

# %%
def print_all(items: list):
    for item in items:
        print(item)

# %%
print_all([1, 2, 3])
# Out:
# 1
# 2
# 3

# %%
print_all("abc")
# Out:
# a
# b
# c

# %% [markdown]
# ### Ranges

# %% [markdown]
# ### Ranges

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(2, 4):
    print(i)
# Out:
# 2
# 3

# %% [markdown]
# ### Micro-Workshop
#
# Schreiben Sie eine Funktion `print_squares(n: int)`, die die Quadrate der
# Zahlen von 1 bis n ausgibt, jeweils ein Element pro Zeile:
#
# ```python
# >>> print_square(3)
# 1**2 = 1
# 2**2 = 4
# 3**2 = 9
# >>>
# ```

# %% [markdown]
# ## Dictionaries

# %%
translations = {"snake": "Schlange", "bat": "Fledermaus", "horse": "Hose"}
