# %% [markdown]
# # Vergleich von Strings

# %%
"a" == 'a'
# Out:
# True

# %%
'A' == 'a'
# Out:
# False

# %%
'A' < 'B'
# Out:
# True

# %%
'A' < 'a'
# Out:
# True

# %%
'a' < 'A'
# Out:
# False

# %% [markdown]
# Strings sind wie im Wörterbuch (lexikographisch) geordnet

# %%
'ab' < 'abc'
# Out:
# True

# %%
'ab' < 'ac'
# Out:
# True

# %%
'ab' != 'ac'
# Out:
# True

# %% [markdown]
# # Nochmal String Literale
#
# - String-Literale werden in einfache oder doppelte Anführungszeichen eingeschlossen
#     - `"Hello, world!"`
#     - `'Hallo Welt!'`
#     - Welche Form man wählt spielt keine Rolle, außer man will Anführungszeichen im String haben
#     - `"Er sagt 'Huh?'"`
#     - `'Sie antwortet: "Genau."'`

# %% [markdown]
# - String-Literale, können Unicode Zeichen enthalten:
#     - `"おはようございます"`
#     - `"😠🙃🙄"`

# %%
print("Er sagt 'Huh?'")
print('Sie antwortet: "Genau."')
print("おはようございます")
print("😠🙃🙄")
# Out:
# Er sagt 'Huh?'
# Sie antwortet: "Genau."
# おはようございます
# 😠🙃🙄

# %% [markdown]
# - Sonderzeichen können mit *Escape-Notation* angegeben werden:
#     - `\n`, `\t`, `\\`, `\"`, `\'`, ...
#     - `\u`, `\U` für Unicode code points (16 bzw. 32 bit)
#     - `\N{...}` für Unicode

# %%
print("a\tbc\td\n123\t4\t5")
# Out:
# a	bc	d
# 123	4	5

# %%
print("\"Let\'s go crazy\", she said")
# Out:
# "Let's go crazy", she said

# %%
print("C:\\Users\\John")
# Out:
# C:\Users\John

# %%
print("\u0394 \u03b1 \t\U000003b2 \U000003b3")
print("\U0001F62E \U0001f61a \U0001f630")
# Out:
# Δ α 	β γ
# 😮 😚 😰

# %%
print("\N{GREEK CAPITAL LETTER DELTA} \N{GREEK SMALL LETTER ALPHA}")
print("\N{smiling face with open mouth and smiling eyes} \N{winking face}")
# Out:
# Δ α
# 😄 😉

# %% [markdown]
# - String Literale können auch in 3-fache Anführungszeichen eingeschlossen werden
# - Diese Art von Literalen kann über mehrere Zeilen gehen

# %%
"""Das ist
ein String-Literal,
das über mehrere
Zeilen geht."""
# Out:
# 'Das ist\nein String-Literal,\ndas über mehrere\nZeilen geht.'

# %%
print('''Mit Backslash am Ende der Zeile \
kann der Zeilenvorschub unterdrückt werden.''')
# Out:
# Mit Backslash am Ende der Zeile kann der Zeilenvorschub unterdrückt werden.

# %% [markdown]
# ## Konkatenation von Strings
#
# Mit `+` können Strings aneinandergehängt (konkateniert) werden:

# %%
"Ein" + " " + "String"
# Out:
# 'Ein String'

# %% [markdown]
# ## Mini-Workshop
#
# - Notebook `015x-Workshop Mehr zu Strings`
# - Abschnitt "Begrüßung 1"

# %% [markdown]
# # String Interpolation: F-Strings
#
# Python bietet die Möglichkeit, Werte von Variablen in Strings einzusetzen:

# %%
name = "Hans"
zahl = 12
f"Hallo {name:12}, die Zahl ist {zahl * 2 + 1:6.1f}!"
# Out:
# 'Hallo Hans        , die Zahl ist   25.0!'

# %%
spieler_name = "Hans"
anzahl_spiele = 10
anzahl_gewinne = 2
print(f"""Hallo {spieler_name},
Sie haben {anzahl_spiele} gespielt \
und davon {anzahl_gewinne} gewonnen.""")
# Out:
# Hallo Hans,
# Sie haben 10 gespielt und davon 2 gewonnen.

# %%
spieler_name = "Hans"
anzahl_spiele = 10
anzahl_gewinne = 2
print(f"Hallo {spieler_name},\n"
      f"Sie haben {anzahl_spiele} gespielt "
      f"und davon {anzahl_gewinne} gewonnen.")
# Out:
# Hallo Hans,
# Sie haben 10 gespielt und davon 2 gewonnen.

# %% [markdown]
# ## Mini-Workshop
#
# - Notebook `015x-Workshop Mehr zu Strings`
# - Abschnitt "Begrüßung 2"

# %% [markdown]
# ## Mini-Workshop
#
# - Notebook `015x-Workshop Mehr zu Strings`
# - Abschnitt "Piraten 4"
